# %% [markdown]
# <a href="https://colab.research.google.com/github/chiusanghung/AI/blob/main/Week12_Pre_trained_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MTCNN
# Multi_Task Cascaded CNN
# Mô hình nhận  dạng khuôn mặt
# VGG16
# ResNet
# R_CNN
# Yolo 8

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 41.2 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

# %%
filename = '/content/drive/MyDrive/AI/arg.jpg'

pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)

for face in faces:
  print(face)
# Out:
# ...
# 10/10 [==============================] - 0s 18ms/step
# {'box': [784, 440, 50, 74], 'confidence': 0.9999996423721313, 'keypoints': {'left_eye': (792, 465), 'right_eye': (813, 464), 'nose': (799, 473), 'mouth_left': (792, 492), 'mouth_right': (814, 491)}}
# {'box': [345, 390, 54, 70], 'confidence': 0.9999978542327881, 'keypoints': {'left_eye': (359, 410), 'right_eye': (383, 412), 'nose': (371, 421), 'mouth_left': (359, 437), 'mouth_right': (381, 439)}}
# {'box': [1019, 383, 54, 82], 'confidence': 0.999997615814209, 'keypoints': {'left_eye': (1040, 409), 'right_eye': (1064, 413), 'nose': (1053, 420), 'mouth_left': (1037, 439), 'mouth_right': (1059, 441)}}
# {'box': [782, 295, 48, 68], 'confidence': 0.9999916553497314, 'keypoints': {'left_eye': (795, 317), 'right_eye': (818, 317), 'nose': (808, 324), 'mouth_left': (798, 343), 'mouth_right': (818, 343)}}
# ...

# %%
filename = '/content/drive/MyDrive/AI/arg.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)

plt.imshow(img)
ax = plt.gca()

for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y),width,height,fill = False, color = 'red')
  ax.add_patch(rect)

  for key,value in face['keypoints'].items():
    dot = plt.Circle(value, radius = 2, color = 'blue')
    ax.add_patch(dot)
plt.show()
# Out:
# 1/1 [==============================] - 0s 365ms/step
# WARNING:tensorflow:5 out of the last 20 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0092659ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# 10/10 [==============================] - 1s 64ms/step

# %%
plt.savefig('argchampion.jpg')

# %%
filename = '/content/drive/MyDrive/AI/people.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)

plt.imshow(img)
ax = plt.gca()

for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y),width,height,fill = False, color = 'red')
  ax.add_patch(rect)

  for key,value in face['keypoints'].items():
    dot = plt.Circle(value, radius = 2, color = 'blue')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 9/9 [==============================] - 1s 39ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height = result_list[i]['box']
    x2,y2 = x1 + width, y1 + height
    plt.subplot(1, len(result_list), i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
  plt.show()

filename = '/content/drive/MyDrive/AI/people.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename, faces)
# Out:
# ...
# 9/9 [==============================] - 0s 16ms/step

# %%
from PIL import Image

def save_faces(file, result_list):
    data = plt.imread(filename)
    for i, result in enumerate(result_list):
        x, y, width, height = result['box']
        face = data[y:y+height, x:x+width]
        Image.fromarray(face).save(f'face_{i}.jpg')
        
save_faces(filename, faces)

# %%
import matplotlib.pyplot as plt

# load the image file
face_img = plt.imread('face_0.jpg')

# display the image
plt.imshow(face_img)
plt.axis('off')
plt.show()
